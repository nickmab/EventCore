# %%
import json
import pandas as pd
import numpy as np

# %%
with open('EventProfiler_original_perf.json', 'r') as f:
    x = json.load(f)
    df = pd.read_json(json.dumps(x['traceEvents']))
    # This has the effect of sorting by which functions were called in which order. 
    # The raw data is logged in order of whatever _returned_ last.
    # We use mergesort because it's a stable sort. 
    # This has the effect of sorting by i) ts ascending (time of original call)
    # and then ii) index descending (so guarantees you see the 'outer' function call
    # appear first in the dataframe, even if they were all called at the 'same' time).
    df = df.sort_index(ascending=False)
    df = df.reset_index()
    df = df.sort_values('ts', kind='mergesort')

# %%
df.head(40)
# Out:
#       index       cat  dur                          name ph  pid        tid  \
# 3996      2  function  116                        OnTick  X    0  170909599
# 3997      1  function   68                        FnCall  X    0  170909599
# 3998      0  function    0       RaiseTCPConnectionEvent  X    0  170909599
# 3995      3  function    0               OnTCPConnection  X    0  170909599
# 3992      6  function   67                        OnTick  X    0  170909599
# 3993      5  function   55                        FnCall  X    0  170909599
# 3994      4  function   21      RaiseNumericMessageEvent  X    0  170909599
# 3991      7  function    0        OnProtoMessageReceived  X    0  170909599
# 3988     10  function   51                        OnTick  X    0  170909599
# 3989      9  function   40                        FnCall  X    0  170909599
# 3990      8  function    4      RaiseTextualMessageEvent  X    0  170909599
# 3987     11  function    1        OnProtoMessageReceived  X    0  170909599
# 3984     14  function   60                        OnTick  X    0  170909599
# 3985     13  function   43                        FnCall  X    0  170909599
# 3986     12  function   16   RaiseArithmeticRequestEvent  X    0  170909599
# 3983     15  function    0        OnProtoMessageReceived  X    0  170909599
# 3980     18  function   60                        OnTick  X    0  170909599
# 3981     17  function   46                        FnCall  X    0  170909599
# 3982     16  function    3  RaiseArithmeticResponseEvent  X    0  170909599
# 3979     19  function    0        OnProtoMessageReceived  X    0  170909599
# 3976     22  function   56                        OnTick  X    0  170909599
# 3977     21  function   41                        FnCall  X    0  170909599
# 3978     20  function    0       RaiseTCPConnectionEvent  X    0  170909599
# 3975     23  function    0               OnTCPConnection  X    0  170909599
# 3972     26  function   48                        OnTick  X    0  170909599
# 3973     25  function   36                        FnCall  X    0  170909599
# 3974     24  function    3      RaiseNumericMessageEvent  X    0  170909599
# 3971     27  function    1        OnProtoMessageReceived  X    0  170909599
# 3968     30  function  190                        OnTick  X    0  170909599
# 3969     29  function  149                        FnCall  X    0  170909599
# 3970     28  function    8      RaiseTextualMessageEvent  X    0  170909599
# 3967     31  function    2        OnProtoMessageReceived  X    0  170909599
# 3964     34  function   54                        OnTick  X    0  170909599
# 3965     33  function   40                        FnCall  X    0  170909599
# 3966     32  function    3   RaiseArithmeticRequestEvent  X    0  170909599
# 3963     35  function    0        OnProtoMessageReceived  X    0  170909599
# 3960     38  function   48                        OnTick  X    0  170909599
# 3961     37  function   37                        FnCall  X    0  170909599
# 3962     36  function    3  RaiseArithmeticResponseEvent  X    0  170909599
# 3959     39  function    1        OnProtoMessageReceived  X    0  170909599
#
#                 ts
# 3996  765599843010
# 3997  765599843011
# 3998  765599843011
# 3995  765599843181
# 3992  765599848013
# 3993  765599848014
# 3994  765599848014
# 3991  765599848092
# 3988  765599853012
# 3989  765599853012
# 3990  765599853013
# 3987  765599853073
# 3984  765599858012
# 3985  765599858013
# 3986  765599858014
# 3983  765599858089
# 3980  765599863013
# 3981  765599863013
# 3982  765599863014
# 3979  765599863087
# 3976  765599868013
# 3977  765599868013
# 3978  765599868014
# 3975  765599868081
# 3972  765599873012
# 3973  765599873013
# 3974  765599873013
# 3971  765599873077
# 3968  765599878022
# 3969  765599878024
# 3970  765599878026
# 3967  765599878246
# 3964  765599883013
# 3965  765599883013
# 3966  765599883014
# 3963  765599883080
# 3960  765599888018
# 3961  765599888018
# 3962  765599888019
# 3959  765599888080
