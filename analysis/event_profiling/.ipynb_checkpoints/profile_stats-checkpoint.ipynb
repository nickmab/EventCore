# %%
import json
import pandas as pd
import numpy as np

# %%
with open('EventProfiler_original_perf.json', 'r') as f:
    x = json.load(f)
    df = pd.read_json(json.dumps(x['traceEvents']))
    df.sort_values('ts', inplace=True)

# %%
df.head(40)
# Out:
#          cat  dur                          name ph  pid         tid  \
# 1   function   44                        OnTick  X    0  4274388155
# 0   function    0       RaiseTCPConnectionEvent  X    0  4274388155
# 2   function    0               OnTCPConnection  X    0  4274388155
# 3   function   10      RaiseNumericMessageEvent  X    0  4274388155
# 4   function   46                        OnTick  X    0  4274388155
# 5   function    0        OnProtoMessageReceived  X    0  4274388155
# 7   function   43                        OnTick  X    0  4274388155
# 6   function    5      RaiseTextualMessageEvent  X    0  4274388155
# 8   function    0        OnProtoMessageReceived  X    0  4274388155
# 10  function   41                        OnTick  X    0  4274388155
# 9   function    9   RaiseArithmeticRequestEvent  X    0  4274388155
# 11  function    1        OnProtoMessageReceived  X    0  4274388155
# 13  function   42                        OnTick  X    0  4274388155
# 12  function    4  RaiseArithmeticResponseEvent  X    0  4274388155
# 14  function    1        OnProtoMessageReceived  X    0  4274388155
# 15  function    1       RaiseTCPConnectionEvent  X    0  4274388155
# 16  function   29                        OnTick  X    0  4274388155
# 17  function    0               OnTCPConnection  X    0  4274388155
# 19  function   40                        OnTick  X    0  4274388155
# 18  function    4      RaiseNumericMessageEvent  X    0  4274388155
# 20  function    1        OnProtoMessageReceived  X    0  4274388155
# 22  function   41                        OnTick  X    0  4274388155
# 21  function    4      RaiseTextualMessageEvent  X    0  4274388155
# 23  function    0        OnProtoMessageReceived  X    0  4274388155
# 24  function    3   RaiseArithmeticRequestEvent  X    0  4274388155
# 25  function   30                        OnTick  X    0  4274388155
# 26  function    1        OnProtoMessageReceived  X    0  4274388155
# 27  function    3  RaiseArithmeticResponseEvent  X    0  4274388155
# 28  function   26                        OnTick  X    0  4274388155
# 29  function    1        OnProtoMessageReceived  X    0  4274388155
# 31  function   40                        OnTick  X    0  4274388155
# 30  function    0       RaiseTCPConnectionEvent  X    0  4274388155
# 32  function    0               OnTCPConnection  X    0  4274388155
# 34  function  121                        OnTick  X    0  4274388155
# 33  function    8      RaiseNumericMessageEvent  X    0  4274388155
# 35  function    2        OnProtoMessageReceived  X    0  4274388155
# 37  function   41                        OnTick  X    0  4274388155
# 36  function    4      RaiseTextualMessageEvent  X    0  4274388155
# 38  function    1        OnProtoMessageReceived  X    0  4274388155
# 39  function    4   RaiseArithmeticRequestEvent  X    0  4274388155
#
#               ts
# 1   763559598058
# 0   763559598059
# 2   763559598151
# 3   763559603061
# 4   763559603061
# 5   763559603121
# 7   763559608060
# 6   763559608061
# 8   763559608117
# 10  763559613059
# 9   763559613060
# 11  763559613112
# 13  763559618060
# 12  763559618061
# 14  763559618118
# 15  763559623060
# 16  763559623060
# 17  763559623096
# 19  763559628070
# 18  763559628071
# 20  763559628121
# 22  763559633060
# 21  763559633061
# 23  763559633115
# 24  763559638061
# 25  763559638061
# 26  763559638099
# 27  763559643060
# 28  763559643060
# 29  763559643093
# 31  763559648061
# 30  763559648061
# 32  763559648113
# 34  763559653116
# 33  763559653118
# 35  763559653277
# 37  763559658769
# 36  763559658770
# 38  763559658826
# 39  763559663768
