# %%
import json
import pandas as pd
import numpy as np

# %%
with open('EventProfiler_original_perf.json', 'r') as f:
    x = json.load(f)
    df = pd.read_json(json.dumps(x['traceEvents']))
    # This has the effect of sorting by which functions were called in which order. 
    # The raw data is logged in order of whatever _returned_ last.
    # We use mergesort because it's a stable sort. 
    # This has the effect of sorting by i) ts ascending (time of original call)
    # and then ii) index descending (so guarantees you see the 'outer' function call
    # appear first in the dataframe, even if they were all called at the 'same' time).
    df = df.sort_index(ascending=False)
    df = df.reset_index()
    df = df.sort_values('ts', kind='mergesort')

# %%
df.head(40)
# Out:
#       index       cat  dur                          name ph  pid         tid  \
# 3996      2  function   96                        OnTick  X    0  3933284505
# 3997      1  function   71                        FnCall  X    0  3933284505
# 3998      0  function    0       RaiseTCPConnectionEvent  X    0  3933284505
# 3995      3  function    0               OnTCPConnection  X    0  3933284505
# 3992      6  function  300                        OnTick  X    0  3933284505
# 3993      5  function   65                        FnCall  X    0  3933284505
# 3994      4  function   17      RaiseNumericMessageEvent  X    0  3933284505
# 3991      7  function    1        OnProtoMessageReceived  X    0  3933284505
# 3988     10  function   20                        OnTick  X    0  3933284505
# 3989      9  function   14                        FnCall  X    0  3933284505
# 3990      8  function    2      RaiseTextualMessageEvent  X    0  3933284505
# 3987     11  function    1        OnProtoMessageReceived  X    0  3933284505
# 3984     14  function   24                        OnTick  X    0  3933284505
# 3985     13  function   19                        FnCall  X    0  3933284505
# 3986     12  function   11   RaiseArithmeticRequestEvent  X    0  3933284505
# 3983     15  function    0        OnProtoMessageReceived  X    0  3933284505
# 3980     18  function   67                        OnTick  X    0  3933284505
# 3981     17  function   54                        FnCall  X    0  3933284505
# 3982     16  function    3  RaiseArithmeticResponseEvent  X    0  3933284505
# 3979     19  function    0        OnProtoMessageReceived  X    0  3933284505
# 3976     22  function   11                        OnTick  X    0  3933284505
# 3977     21  function    6                        FnCall  X    0  3933284505
# 3978     20  function    0       RaiseTCPConnectionEvent  X    0  3933284505
# 3975     23  function    0               OnTCPConnection  X    0  3933284505
# 3972     26  function   20                        OnTick  X    0  3933284505
# 3973     25  function   15                        FnCall  X    0  3933284505
# 3974     24  function    2      RaiseNumericMessageEvent  X    0  3933284505
# 3971     27  function    0        OnProtoMessageReceived  X    0  3933284505
# 3968     30  function   17                        OnTick  X    0  3933284505
# 3969     29  function   12                        FnCall  X    0  3933284505
# 3970     28  function    2      RaiseTextualMessageEvent  X    0  3933284505
# 3967     31  function    0        OnProtoMessageReceived  X    0  3933284505
# 3964     34  function   39                        OnTick  X    0  3933284505
# 3965     33  function   31                        FnCall  X    0  3933284505
# 3966     32  function    3   RaiseArithmeticRequestEvent  X    0  3933284505
# 3963     35  function    0        OnProtoMessageReceived  X    0  3933284505
# 3960     38  function   12                        OnTick  X    0  3933284505
# 3961     37  function    6                        FnCall  X    0  3933284505
# 3962     36  function    0  RaiseArithmeticResponseEvent  X    0  3933284505
# 3959     39  function    0        OnProtoMessageReceived  X    0  3933284505
#
#                 ts
# 3996  765371405340
# 3997  765371405341
# 3998  765371405341
# 3995  765371405498
# 3992  765371410341
# 3993  765371410341
# 3994  765371410341
# 3991  765371410656
# 3988  765371415339
# 3989  765371415339
# 3990  765371415339
# 3987  765371415364
# 3984  765371420339
# 3985  765371420339
# 3986  765371420339
# 3983  765371420369
# 3980  765371425342
# 3981  765371425343
# 3982  765371425343
# 3979  765371425416
# 3976  765371430339
# 3977  765371430339
# 3978  765371430339
# 3975  765371430356
# 3972  765371435339
# 3973  765371435339
# 3974  765371435339
# 3971  765371435365
# 3968  765371440339
# 3969  765371440339
# 3970  765371440339
# 3967  765371440362
# 3964  765371445343
# 3965  765371445344
# 3966  765371445344
# 3963  765371445388
# 3960  765371450339
# 3961  765371450340
# 3962  765371450340
# 3959  765371450356
